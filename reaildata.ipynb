# %% [markdown]
# <a href="https://colab.research.google.com/github/SvicideRyde/Testing/blob/practice/reaildata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("new_retail_data.csv")

df.head()
# Out:
#    Transaction_ID  Customer_ID                 Name                Email  \
# 0       8691788.0      37249.0  Michelle Harrington    Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill     Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen    Shane85@gmail.com
# 3       7232460.0      62101.0        Joseph Miller     Mary34@gmail.com
# 4       4983775.0      27901.0        Debra Coleman  Charles30@gmail.com
#
#           Phone                      Address        City            State  \
# 0  1.414787e+09            3959 Amanda Burgs    Dortmund           Berlin
# 1  6.852900e+09           82072 Dawn Centers  Nottingham          England
# 2  8.362160e+09            4133 Young Canyon     Geelong  New South Wales
# 3  2.776752e+09  8148 Thomas Creek Suite 100    Edmonton          Ontario
# 4  9.098268e+09    5813 Lori Ports Suite 269     Bristol          England
#
#    Zipcode    Country  ...  Total_Amount Product_Category  Product_Brand  \
# ...

# %%
df.isnull().sum()
# Out:
# Transaction_ID      56
# Customer_ID         62
# Name                42
# Email               60
# Phone               76
# Address             51
# City                16
# State               31
# Zipcode             57
# Country             24
# Age                  3
# Gender              71
# Income              19
# Customer_Segment     0
# Date                69
# Year                54
# Month               79
# Time                56
# Total_Purchases     57
# Amount              47
# Total_Amount        68
# Product_Category    57
# Product_Brand       49
# Product_Type         1
# Feedback            66
# Shipping_Method     71
# Payment_Method      58
# Order_Status        29
# Ratings             66
# products             1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_new = df.apply(lambda x: x.fillna(x.mode()[0]), axis=0)
df_new.isnull().sum()
# Out:
# Transaction_ID      0
# Customer_ID         0
# Name                0
# Email               0
# Phone               0
# Address             0
# City                0
# State               0
# Zipcode             0
# Country             0
# Age                 0
# Gender              0
# Income              0
# Customer_Segment    0
# Date                0
# Year                0
# Month               0
# Time                0
# Total_Purchases     0
# Amount              0
# Total_Amount        0
# Product_Category    0
# Product_Brand       0
# Product_Type        0
# Feedback            0
# Shipping_Method     0
# Payment_Method      0
# Order_Status        0
# Ratings             0
# products            0
# dtype: int64

# %%
df_new.duplicated().sum()
# Out:
# 0

# %%
df_new.to_csv(retail_data_update.csv, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-205147561011> in <cell line: 1>()
# ----> 1 df_new.to_csv(retail_data_update.csv, index=False)
#
# NameError: name 'retail_data_update' is not defined
